# %% [markdown]
# { “nbformat”: 4, “nbformat_minor”: 0, “metadata”: { “colab”: {
# “provenance”: \[\] }, “kernelspec”: { “name”: “python3”, “display_name”:
# “Python 3” }, “language_info”: { “name”: “python” } }, “cells”: \[ {
# “cell_type”: “markdown”, “source”: \[ “ECE2112 - PA1” \], “metadata”: {
# “id”: “ZVsmOzwlGGV9” } }, { “cell_type”: “markdown”, “source”: \[ “NAME:
# MALLARI, Marcus Andre, A.”, “SECTION: \| 2ECE-B \|”, “DATE SUBMITTED:
# AUGUST, 27, 2026”, “” \], “metadata”: { “id”: “synVxuQG_e5A” } }, {
# “cell_type”: “markdown”, “source”: \[ “A. WORD ROTATION PROBLEM” \],
# “metadata”: { “id”: “p0Tk0KQz9lwc” } }, { “cell_type”: “code”, “source”:
# \[ “def rotate_word(text): #This slices from index 1 to the end, then it
# appends the index 0.”, ” return text\[1:\] + text\[0\]” \], “metadata”:
# { “id”: “2vNm_srp9i_7” }, “execution_count”: null, “outputs”: \[\] }, {
# “cell_type”: “code”, “source”: \[ “#Code testing”,
# “print(rotate_word("python"))”, “print(rotate_word("logic"))”,
# “print(rotate_word("Code"))”, “print(rotate_word("A"))” \], “metadata”:
# { “colab”: { “base_uri”: “https://localhost:8080/” }, “id”:
# “NWozDKEnEmC7”, “outputId”: “08509113-06a3-43b1-865a-c01c91b78aa2” },
# “execution_count”: null, “outputs”: \[ { “output_type”: “stream”,
# “name”: “stdout”, “text”: \[ “ythonp”, “ogicl”, “odeC”, “A” \] } \] }, {
# “cell_type”: “markdown”, “source”: \[ “B. USERNAME BUILDER PROBLEM” \],
# “metadata”: { “id”: “TFS55a_TGlTA” } }, { “cell_type”: “code”, “source”:
# \[ “def make_username(first_name, last_name):”, ” #Convert first name
# and last name to lowercases and remove the spaces.“,” #Combine the first
# name and the last name with a period.“,” return
# first_name.lower().replace(" ", "") + "." + last_name.lower().replace("
# ","")” \], “metadata”: { “id”: “IdzhLi4M9Itj” }, “execution_count”:
# null, “outputs”: \[\] }, { “cell_type”: “code”, “source”: \[ “#Code
# testing”, “print(make_username("Ada", "Lovelace"))”,
# “print(make_username("Alan", "Turing"))”, “print(make_username("Ana
# Maria", "De Leon"))” \], “metadata”: { “colab”: { “base_uri”:
# “https://localhost:8080/” }, “id”: “xai0vttXEwyl”, “outputId”:
# “b3c93c5c-e744-4834-afff-aecd1aefb30c” }, “execution_count”: null,
# “outputs”: \[ { “output_type”: “stream”, “name”: “stdout”, “text”: \[
# “ada.lovelace”, “alan.turing”, “anamaria.deleon” \] } \] }, {
# “cell_type”: “markdown”, “source”: \[ “C.BOOKEND SWAP PROBLEM” \],
# “metadata”: { “id”: “qvIPvLkrVTjG” } }, { “cell_type”: “code”, “source”:
# \[ “def swap_bookends(items):”, ” #Make the first, *middle, and last
# elements as a list.“,” first, *middle, last = items“,” #Then we combine
# the list with last element first and the first element to last.“,”
# return \[last\] + middle + \[first\]” \], “metadata”: { “id”:
# “IoYdTtk59Ioy” }, “execution_count”: null, “outputs”: \[\] }, {
# “cell_type”: “code”, “source”: \[ “#Code testing”,
# “print(swap_bookends(\[1, 2, 3, 4, 5, 6\]))”,
# “print(swap_bookends(\["red", "green", "blue"\]))”,
# “print(swap_bookends(\[8, 3\]))” \], “metadata”: { “colab”: {
# “base_uri”: “https://localhost:8080/” }, “id”: “zrwFzO7mE_BO”,
# “outputId”: “ab23af64-af46-439f-963f-dd048fb8c0a1” }, “execution_count”:
# null, “outputs”: \[ { “output_type”: “stream”, “name”: “stdout”, “text”:
# \[ “\[6, 2, 3, 4, 5, 1\]”, “\[‘blue’, ‘green’, ‘red’\]”, “\[3, 8\]” \] }
# \] } \] }
